# %%
# Initial imports
import os
import pandas as pd
from pathlib import Path
from newsapi import NewsApiClient
from dotenv import load_dotenv
load_dotenv()

# Retrieve the News API key
api_key = os.getenv("NEWS_API_KEY")

# Create the newsapi client
newsapi = NewsApiClient(api_key=api_key)

# Verification of API key for NewsApi
# Should be 'str' and 32

print(type(api_key))
print(len(api_key))
# Out:
# <class 'str'>
# 32

# %%
newsapi.get_everything(q="Democrat",language="en")
# Out:
# {'status': 'ok',
#  'totalResults': 22204,
#  'articles': [{'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Jonathan Martin',
#    'title': 'Biden Holds Steady Lead Over Trump in Arizona, Latest Poll Finds',
#    'description': 'The Democratic nominee leads 49 percent to 41 percent in Arizona, a state that hasn’t voted for a Democrat for president since 1996. In the Senate race, Mark Kelly, a Democrat, leads the incumbent, Martha McSally.',
#    'url': 'https://www.nytimes.com/2020/10/05/us/elections/politics-arizona-poll.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/10/05/multimedia/05arizonapoll/05arizonapoll-facebookJumbo.jpg',
#    'publishedAt': '2020-10-05T17:03:52Z',
#    'content': 'Mr. Trumps relatively narrow margin of victory in Arizona four years ago made clear the state was undergoing a political metamorphosis and Ms. Sinemas victory there in 2018 left little doubt it would… [+1810 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Emma G. Fitzsimmons',
#    'title': 'Andy King, N.Y. City Council Member, Faces Expulsion for Misconduct',
#    'description': 'Andy King, a Bronx Democrat, might lose his job after facing a third ethics investigation.',
#    'url': 'https://www.nytimes.com/2020/10/05/nyregion/andy-king-council-expelled.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/10/05/nyregion/05andyking1/05andyking1-facebookJumbo.jpg',
#    'publishedAt': '2020-10-05T16:45:59Z',
#    'content': 'Mr. King stood silently next to Mr. Jackson on Friday, wearing a face mask and one of his trademark bow ties. Mr. King planned to defend himself at the Council hearing on Monday, Mr. Jackson said.\r\nA… [+1934 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Emma G. Fitzsimmons',
#    'title': 'Andy King Removed From New York City Council After Ethics Inquiries',
#    'description': 'Andy King, a Bronx Democrat, was voted out after facing three ethics inquiries.',
#    'url': 'https://www.nytimes.com/2020/10/05/nyregion/andy-king-city-council.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/10/05/nyregion/05andyking1/05andyking1-facebookJumbo.jpg',
#    'publishedAt': '2020-10-05T21:27:26Z',
#    'content': 'Mr. King was also accused of giving another staff member an extra payment of $9,500 in 2019 and forcing the staff member to give him back $2,000 in cash. Mr. King also failed to pay the fine imposed … [+1539 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Nicholas Bogel-Burroughs and Shaila Dewan',
#    'title': 'F.B.I. Says Michigan Militia Plotted to Kidnap Gov. Gretchen Whitmer',
#    'description': 'Six men had been discussing taking Ms. Whitmer, a Democrat, hostage since at least the summer, the F.B.I. said.',
#    'url': 'https://www.nytimes.com/2020/10/08/us/gretchen-whitmer-michigan-militia.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/10/08/us/08plot-1/merlin_177438252_4ff1c3f6-399f-4700-a2b0-96ff3e216adc-facebookJumbo.jpg',
#    'publishedAt': '2020-10-08T16:28:32Z',
#    'content': 'Six men were arrested and accused of plotting with a militia group to kidnap Gov. Gretchen Whitmer of Michigan, the authorities announced on Thursday.\r\nThe men, some of whom the F.B.I. said had discu… [+1165 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Jazmine Hughes',
#    'title': 'Rep. Max Rose Seeks 2nd Term by Targeting Fellow Democrat: De Blasio',
#    'description': 'The Republican candidate is Nicole Malliotakis, but in a conservative congressional district, Mr. Rose is also happy to run against the mayor.',
#    'url': 'https://www.nytimes.com/2020/10/13/nyregion/max-rose-nicole-malliotakis.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/09/28/nyregion/00ny-maxrose/00ny-maxrose-facebookJumbo.jpg',
#    'publishedAt': '2020-10-13T09:00:23Z',
#    'content': 'Its easy, when youre a Republican, to criticize someone in charge, Mr. Rose said. Its hard to criticize someone in your own party.\r\nThat is not entirely true in Mr. Roses case.\r\nIn his successful 201… [+1264 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "US election: Biden says Florida seniors 'expendable' for Trump",
#    'description': 'The Democrat meets senior voters in the battleground state, a day after the president held a rally.',
#    'url': 'https://www.bbc.co.uk/news/election-us-2020-54533480',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/158D7/production/_114897288_hi063809777.jpg',
#    'publishedAt': '2020-10-13T22:19:33Z',
#    'content': 'image captionJoe Biden told older voters they were "expendable" to Donald Trump\r\nUS Democratic presidential candidate Joe Biden has criticised Donald Trump\'s handling of the coronavirus pandemic whil… [+3125 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Fredreka Schouten and Sarah Mucha, CNN',
#    'title': 'Joe Biden entered fall campaign with $466 million in the bank',
#    'description': "Democrat Joe Biden's campaign and aligned Democratic Party committees entered September and the fall sprint to Election Day with $466 million in cash reserves -- giving the former vice president a significant financial advantage over President Donald Trump.",
#    'url': 'https://www.cnn.com/2020/09/20/politics/joe-biden-entered-fall-campaign-with-466-million-in-the-bank/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200917220906-115-biden-town-hall-0917-super-tease.jpg',
#    'publishedAt': '2020-09-21T01:18:18Z',
#    'content': None},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Maegan Vazquez and Nikki Carvajal, CNN',
#    'title': 'Trump made another baseless political claim about Fauci',
#    'description': "President Donald Trump baselessly claimed on Thursday that Dr. Anthony Fauci, a key member of the White House's Coronavirus Task Force, was a Democrat when in fact he is not registered with any political party.",
#    'url': 'https://www.cnn.com/2020/10/15/politics/anthony-fauci-trump-democrat-political-party/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/201011152609-file-donald-trump-anthony-fauci-0317-super-tease.jpg',
#    'publishedAt': '2020-10-15T23:55:07Z',
#    'content': "Washington (CNN)President Donald Trump baselessly claimed on Thursday that Dr. Anthony Fauci, a key member of the White House's Coronavirus Task Force, was a Democrat when in fact he is not registere… [+3397 chars]"},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Jesse McKinley and Luis Ferré-Sadurní',
#    'title': 'Cuomo Won’t Approve Closing of Businesses in 9 Hard-Hit N.Y.C. Areas',
#    'description': 'The abrupt announcement caused confusion over the official response to virus spikes and threatened to deepen tensions with the mayor.',
#    'url': 'https://www.nytimes.com/2020/10/05/nyregion/cuomo-shutdown-coronavirus.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/10/05/nyregion/05nyvirus-cuomo/05nyvirus-cuomo-facebookJumbo.jpg',
#    'publishedAt': '2020-10-05T17:58:14Z',
#    'content': 'ALBANY, N.Y. Gov. Andrew M. Cuomo on Monday refused to allow New York City to close nonessential businesses in nine hot spots in Brooklyn and Queens where the coronavirus has spiked, pre-empting a pl… [+560 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Nicholas Fandos',
#    'title': 'Republicans Close In on Barrett Confirmation to Supreme Court',
#    'description': 'The Senate Judiciary Committee lined up a vote for Oct. 22 on Judge Amy Coney Barrett’s nomination to the Supreme Court, as Democrats warned Republicans would rue the day.',
#    'url': 'https://www.nytimes.com/2020/10/15/us/politics/senate-amy-coney-barrett-confirmation.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/10/15/us/politics/15dc-barrett-sub1/15dc-barrett-sub1-facebookJumbo.jpg',
#    'publishedAt': '2020-10-15T21:45:31Z',
#    'content': 'The rule of because we can, which is the rule being applied today, is one that leads away from a lot of the traditions and comity and values that the Senate has long embodied, said Senator Sheldon Wh… [+1078 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': '

#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201006&t=2&i=1536422380&r=LYNXMPEG951XV&w=800',
#    'publishedAt': '2020-10-06T19:23:00Z',
#    'content': 'WASHINGTON (Reuters) - Democratic Senate challenger Cal Cunningham appears to lead incumbent Senator Thom Tillis in North Carolina, according to a Reuters/Ipsos poll taken as the news broke of Tillis… [+2496 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Joseph Ax',
#    'title': 'Democrat Biden to outline how he would oversee coronavirus vaccine - Reuters India',
#    'description': "Democratic presidential candidate Joe Biden will lay out on Wednesday how he plans if elected to develop and distribute a safe coronavirus vaccine, seeking to draw a contrast with President Donald Trump's approach to combating the pandemic.",
#    'url': 'https://in.reuters.com/article/usa-election-biden-idINKBN2671M2',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20200916&t=2&i=1533665720&r=LYNXMPEG8F0XU&w=800',
#    'publishedAt': '2020-09-16T10:19:00Z',
#    'content': '(Reuters) - Democratic presidential candidate Joe Biden will lay out on Wednesday how he plans if elected to develop and distribute a safe coronavirus vaccine, seeking to draw a contrast with Preside… [+3927 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Democrat Schumer says Ginsburg vacancy should be filled by new president - Reuters UK',
#    'description': 'U.S. Senate Democratic leader Chuck Schumer said on Friday the Supreme Court vacancy created by the death of Justice Ruth Bader Ginsburg should not be filled until there is a new president.',
#    'url': 'https://in.reuters.com/article/uk-usa-court-ginsburg-schumer-idUKKBN26A00E',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20200919&t=2&i=1534067260&r=LYNXMPEG8I00M&w=800',
#    'publishedAt': '2020-09-19T00:17:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: U.S. Senate Minority Leader Chuck Schumer, joined by Speaker of the House Nancy Pelosi, speaks to reporters in the U.S. Capitol in Washington, U.S. July 29, 2020. REUTER… [+416 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Trump offered to pardon Assange if he provided source Democrat emails link, lawyer says - Reuters UK',
#    'description': 'U.S. President Donald Trump offered to pardon Julian Assange if the WikiLeaks founder provided the source for the hacking of Democratic National Committee emails before the 2016 U.S. presidential election, a London court was told on Friday.',
#    'url': 'https://uk.reuters.com/article/uk-britain-assange-idUKKBN2691XD',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20200918&t=2&i=1533994807&r=LYNXMPEG8H115&w=800',
#    'publishedAt': '2020-09-18T12:23:00Z',
#    'content': "By Reuters Staff\r\nFILE PHOTO: WikiLeaks' founder Julian Assange leaves Westminster Magistrates Court in London, Britain January 13, 2020. REUTERS/Henry Nicholls\r\nLONDON (Reuters) - U.S. President Don… [+912 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Democrat Biden started September with nearly half a billion in cash, official says - Reuters',
#    'description': 'Democratic U.S. presidential nominee Joe Biden and affiliated party groups held $466 million in cash at the beginning of September, according to a campaign official familiar with the fundraising.',
#    'url': 'https://www.reuters.com/article/us-usa-election-fundraising-idUSKCN26C00F',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20200921&t=2&i=1534233505&r=LYNXNPEG8K00A&w=800',
#    'publishedAt': '2020-09-21T00:29:00Z',
#    'content': 'By Reuters Staff\r\nDemocratic U.S. presidential nominee and former Vice President Joe Biden removes his face mask before delivering remarks regarding the Supreme Court at the National Constitution Cen… [+488 chars]'}]}

# %%
def create_df(news):
    """
    create_df takes in a json file created by NewsAPI and returns
    a dataframe of key information on the queried subject.
    """
    
    #Creating an open list of dictionaries to create a Dataframe later on.
    articles = []
    
    #Going through the articles found and using a Try/Except block to not break code.
    for article in news:
        
        try:
            
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "Title": title,
                "Description": description,
                "Text": text,
                "Date": date,
            })
            
        except AttributeError:
            
            pass

    return pd.DataFrame(articles)

# %%
create_df(newsapi.get_everything(q="Democrat",language="en")['articles'])
